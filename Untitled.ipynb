# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("EdStatsCountry.csv")

# %%
df
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 236          XKX        Kosovo        Kosovo            Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 238          ZAF  South Africa  South Africa      Republic of South Africa
# 239          ZMB        Zambia        Zambia            Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #les dimensions
# Out:
# (241, 32)

# %%
df.columns #les columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
df.head() #les 5 premiers
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df.head(10)
# Out:
#   Country Code            Short Name            Table Name  \
# 0          ABW                 Aruba                 Aruba
# 1          AFG           Afghanistan           Afghanistan
# 2          AGO                Angola                Angola
# 3          ALB               Albania               Albania
# 4          AND               Andorra               Andorra
# 5          ARB            Arab World            Arab World
# 6          ARE  United Arab Emirates  United Arab Emirates
# 7          ARG             Argentina             Argentina
# 8          ARM               Armenia               Armenia
# 9          ASM        American Samoa        American Samoa
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# 1  Islamic State of Afghanistan           AF  Afghan afghani
# 2   People's Republic of Angola           AO  Angolan kwanza
# 3           Republic of Albania           AL    Albanian lek
# ...

# %%
df.tail() #les 5 derniers
# Out:
#     Country Code    Short Name    Table Name                 Long Name  \
# 236          XKX        Kosovo        Kosovo        Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.         Republic of Yemen
# 238          ZAF  South Africa  South Africa  Republic of South Africa
# 239          ZMB        Zambia        Zambia        Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe      Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# 236          NaN                Euro
# 237           YE         Yemeni rial
# 238           ZA  South African rand
# 239           ZM  New Zambian kwacha
# 240           ZW         U.S. dollar
#
#                                          Special Notes  \
# 236  Kosovo became a World Bank member on June 29, ...
# 237  Based on official government statistics and In...
# 238  Fiscal year end: March 31; reporting period fo...
# 239  National accounts data have rebased to reflect...
# ...

# %%
df.tail(1)
# Out:
#     Country Code Short Name Table Name             Long Name 2-alpha code  \
# 240          ZWE   Zimbabwe   Zimbabwe  Republic of Zimbabwe           ZW
#
#     Currency Unit                                      Special Notes  \
# 240   U.S. dollar  Fiscal year end: June 30; reporting period for...
#
#                  Region Income Group WB-2 code  ...  \
# 240  Sub-Saharan Africa   Low income        ZW  ...
#
#               IMF data dissemination standard  Latest population census  \
# 240  General Data Dissemination System (GDDS)                      2012
#
#                           Latest household survey  \
# 240  Demographic and Health Survey (DHS), 2010/11
#
#     Source of most recent Income and expenditure data  \
# 240        Integrated household survey (IHS), 2011/12
#
#     Vital registration complete Latest agricultural census  \
# 240                         NaN                        NaN
#
# ...

# %%
df['Region']
# Out:
# 0       Latin America & Caribbean
# 1                      South Asia
# 2              Sub-Saharan Africa
# 3           Europe & Central Asia
# 4           Europe & Central Asia
#                   ...
# 236         Europe & Central Asia
# 237    Middle East & North Africa
# 238            Sub-Saharan Africa
# 239            Sub-Saharan Africa
# 240            Sub-Saharan Africa
# Name: Region, Length: 241, dtype: object

# %%
x=df['Region']
x
# Out:
# 0       Latin America & Caribbean
# 1                      South Asia
# 2              Sub-Saharan Africa
# 3           Europe & Central Asia
# 4           Europe & Central Asia
#                   ...
# 236         Europe & Central Asia
# 237    Middle East & North Africa
# 238            Sub-Saharan Africa
# 239            Sub-Saharan Africa
# 240            Sub-Saharan Africa
# Name: Region, Length: 241, dtype: object

# %%
y=df['Latest population census']
y
# Out:
# 0                                                   2010
# 1                                                   1979
# 2                                                   1970
# 3                                                   2011
# 4      2011. Population figures compiled from adminis...
#                              ...
# 236                                                 2011
# 237                                                 2004
# 238                                                 2011
# 239                                                 2010
# 240                                                 2012
# Name: Latest population census, Length: 241, dtype: object

# %%
y.describe()
# Out:
# count      213
# unique      27
# top       2011
# freq        59
# Name: Latest population census, dtype: object

# %%
y.count()
# Out:
# 213

# %%
z=df[['Short Name','Table Name','Long Name']]
z
# Out:
#        Short Name    Table Name                     Long Name
# 0           Aruba         Aruba                         Aruba
# 1     Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2          Angola        Angola   People's Republic of Angola
# 3         Albania       Albania           Republic of Albania
# 4         Andorra       Andorra       Principality of Andorra
# ..            ...           ...                           ...
# 236        Kosovo        Kosovo            Republic of Kosovo
# 237         Yemen   Yemen, Rep.             Republic of Yemen
# 238  South Africa  South Africa      Republic of South Africa
# 239        Zambia        Zambia            Republic of Zambia
# 240      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
# [241 rows x 3 columns]

# %%
z.describe()
# Out:
#        Short Name Table Name Long Name
# count         241        241       241
# unique        241        241       241
# top         Aruba      Aruba     Aruba
# freq            1          1         1

# %%
z['Table Name']
# Out:
# 0             Aruba
# 1       Afghanistan
# 2            Angola
# 3           Albania
# 4           Andorra
#            ...
# 236          Kosovo
# 237     Yemen, Rep.
# 238    South Africa
# 239          Zambia
# 240        Zimbabwe
# Name: Table Name, Length: 241, dtype: object

# %%
z['Table Name'].value_counts()
# Out:
# Table Name
# Aruba         1
# St. Lucia     1
# Mauritania    1
# Mauritius     1
# Malawi        1
#              ..
# Greenland     1
# Guatemala     1
# Guam          1
# Guyana        1
# Zimbabwe      1
# Name: count, Length: 241, dtype: int64
